# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv("Downloads/Weight of copper dataset.csv")
df
# Out:
#      Unnamed: 0  power_rating  weight_of_copper category
# 0             1         16.46             34.69     high
# 1             2         12.52             28.78     high
# 2             3          7.66             21.48     high
# 3             4         21.09             41.64     high
# 4             5         24.43             46.64     high
# ..          ...           ...               ...      ...
# 295         296         27.26             50.89     high
# 296         297         46.72             80.07      low
# 297         298         48.99             83.48     high
# 298         299         49.58             84.37     high
# 299         300         37.20             65.80     high
#
# [300 rows x 4 columns]

# %%
plt.xlabel('POWER RATING')
plt.ylabel('AMOUNT OF COPPER')
plt.title('COPPER PREDICTION IN GENERATOR')
plt.hist(df[['power_rating','weight_of_copper']])
# Out:
# (array([[49., 66., 53., 46., 45., 41.,  0.,  0.,  0.,  0.],
#         [ 0.,  9., 38., 46., 39., 32., 41., 22., 31., 42.]]),
#  array([ 5.07, 13.  , 20.93, 28.86, 36.79, 44.72, 52.65, 60.58, 68.51,
#         76.44, 84.37]),
#  <a list of 2 BarContainer objects>)

# %%
len(x_train)
# Out:
# 210

# %%
len(y_train)
# Out:
# 210

# %%
len(x_test)
# Out:
# 90

# %%
len(y_test)
# Out:
# 90

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
