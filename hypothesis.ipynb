# %%
import numpy as np
def find_s_algorithm(examples):
    hypothesis=[None]*(len(examples[0])-1)
    for example in examples:
        if example[-1]=='Yes':
            for i in range(len(hypothesis)):
                if hypothesis[i] is None: 
                    hypothesis[i] = example[i] 
                elif hypothesis[i] != example[i]:
                    hypothesis[i] = '?' 
    return hypothesis 
training_data = [ 
        ['Sunny', 'Cold', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'], 
        ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Same', 'Yes'], 
        ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Same', 'No'], 
        ['Sunny', 'Cold', 'High', 'Weak', 'Cool', 'Change', 'No'] 
        ] 
hypothesis = find_s_algorithm(training_data) 
print("The most specific hypothesis is:", hypothesis)
# Out:
# The most specific hypothesis is: ['Sunny', '?', '?', 'Strong', '?', 'Same']
